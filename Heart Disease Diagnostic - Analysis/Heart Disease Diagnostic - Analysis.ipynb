# %% [markdown]
# # Project Title : Heart Disease Diagnostic - Analysis
#
# # Technologies : Business Intelligence
#
# # Domain : Healthcare

# %% [markdown]
# #

# %% [markdown]
# # importing Libraries

# %%
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np

import seaborn as sns
sns.set_style('whitegrid')

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"reprocessed.hungarian.data")

# %%
df
# Out:
#        40    1    2    140    289    0  0.1    172  0.2  0.3   -9  -9.1  -9.2  \
# 0    49.0  0.0  3.0  160.0  180.0  0.0  0.0  156.0  0.0  1.0  2.0  -9.0  -9.0
# 1    37.0  1.0  2.0  130.0  283.0  0.0  1.0   98.0  0.0  0.0 -9.0  -9.0  -9.0
# 2    48.0  0.0  4.0  138.0  214.0  0.0  0.0  108.0  1.0  1.5  2.0  -9.0  -9.0
# 3    54.0  1.0  3.0  150.0   -9.0  0.0  0.0  122.0  0.0  0.0 -9.0  -9.0  -9.0
# 4    39.0  1.0  3.0  120.0  339.0  0.0  0.0  170.0  0.0  0.0 -9.0  -9.0  -9.0
# ..    ...  ...  ...    ...    ...  ...  ...    ...  ...  ...  ...   ...   ...
# 289  36.0  1.0  2.0  120.0  166.0  0.0  0.0  180.0  0.0  0.0 -9.0  -9.0  -9.0
# 290  48.0  1.0  3.0  110.0  211.0  0.0  0.0  138.0  0.0  0.0 -9.0  -9.0   6.0
# 291  47.0  0.0  2.0  140.0  257.0  0.0  0.0  135.0  0.0  1.0  1.0  -9.0  -9.0
# 292  53.0  1.0  4.0  130.0  182.0  0.0  0.0  148.0  0.0  0.0 -9.0  -9.0  -9.0
# 293   NaN  NaN  NaN    NaN    NaN  NaN  NaN    NaN  NaN  NaN  NaN   NaN   NaN
#
#      0.4
# 0    1.0
# 1    0.0
# ...

# %%
df = pd.read_csv(r"reprocessed.hungarian.data", header = 1, names = ['age', 'sex', 'cp', 'trestbps',
                                                                     'chol', 'fbs', 'restecg', 'thalach',
                                                                     'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num'])

# %%
df
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    37.0  1.0  2.0     130.0  283.0  0.0      1.0     98.0    0.0      0.0
# 1    48.0  0.0  4.0     138.0  214.0  0.0      0.0    108.0    1.0      1.5
# 2    54.0  1.0  3.0     150.0   -9.0  0.0      0.0    122.0    0.0      0.0
# 3    39.0  1.0  3.0     120.0  339.0  0.0      0.0    170.0    0.0      0.0
# 4    45.0  0.0  2.0     130.0  237.0  0.0      0.0    170.0    0.0      0.0
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 288  36.0  1.0  2.0     120.0  166.0  0.0      0.0    180.0    0.0      0.0
# 289  48.0  1.0  3.0     110.0  211.0  0.0      0.0    138.0    0.0      0.0
# 290  47.0  0.0  2.0     140.0  257.0  0.0      0.0    135.0    0.0      1.0
# 291  53.0  1.0  4.0     130.0  182.0  0.0      0.0    148.0    0.0      0.0
# 292   NaN  NaN  NaN       NaN    NaN  NaN      NaN      NaN    NaN      NaN
#
#      slope   ca  thal  num
# 0     -9.0 -9.0  -9.0  0.0
# ...

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num'],
#       dtype='object')

# %% [markdown]
# ## There are fourteen features in Dataset
#
#  - age :  The person's age in years
#
#
#  - sex: The person's sex (1 = male, 0 = female)
#
#
#  - cp: chest pain type
#         -- Value 1: typical angina
#         -- Value 2: atypical angina
#         -- Value 3: non-anginal pain
#         -- Value 4: asymptomatic
#
#
#  - trestbps: resting blood pressure (in mm Hg on admission to the hospital)
#
#
#  - chol: serum cholestoral in mg/dl
#
#
#  - fbs: (fasting blood sugar > 120 mg/dl) (1 = true; 0 = false)
#
#
#  - restecg: resting electrocardiographic results
#         -- Value 0: normal
#         -- Value 1: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV)
#         -- Value 2: showing probable or definite left ventricular hypertrophy by Estes' criteria
#
#
#  - thalach: maximum heart rate achieved
#
#
#  - exang: exercise induced angina (1 = yes; 0 = no)
#
#
#  - oldpeak = ST depression induced by exercise relative to rest
#
#
#  - slope: the slope of the peak exercise ST segment
#         -- Value 1: upsloping
#         -- Value 2: flat
#         -- Value 3: downsloping
#
#
#  -  ca: number of major vessels (0-3) colored by flourosopy
#
#
#  -  thal: 3 = normal; 6 = fixed defect; 7 = reversable defect
#
#
#  - num: diagnosis of heart disease (angiographic disease status)
#         -- Value 0: < 50% diameter narrowing (0=no)
#         -- Value 1: > 50% diameter narrowing (1=yes)

# %%
df_copy = df.copy()
df_copy
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    37.0  1.0  2.0     130.0  283.0  0.0      1.0     98.0    0.0      0.0
# 1    48.0  0.0  4.0     138.0  214.0  0.0      0.0    108.0    1.0      1.5
# 2    54.0  1.0  3.0     150.0   -9.0  0.0      0.0    122.0    0.0      0.0
# 3    39.0  1.0  3.0     120.0  339.0  0.0      0.0    170.0    0.0      0.0
# 4    45.0  0.0  2.0     130.0  237.0  0.0      0.0    170.0    0.0      0.0
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 288  36.0  1.0  2.0     120.0  166.0  0.0      0.0    180.0    0.0      0.0
# 289  48.0  1.0  3.0     110.0  211.0  0.0      0.0    138.0    0.0      0.0
# 290  47.0  0.0  2.0     140.0  257.0  0.0      0.0    135.0    0.0      1.0
# 291  53.0  1.0  4.0     130.0  182.0  0.0      0.0    148.0    0.0      0.0
# 292   NaN  NaN  NaN       NaN    NaN  NaN      NaN      NaN    NaN      NaN
#
#      slope   ca  thal  num
# 0     -9.0 -9.0  -9.0  0.0
# ...

# %%
df_copy.loc[df_copy['num'] > 0, 'num'] = 1

# %%
df_copy.isnull().sum()
# Out:
# age         1
# sex         1
# cp          1
# trestbps    1
# chol        1
# fbs         1
# restecg     1
# thalach     1
# exang       1
# oldpeak     1
# slope       1
# ca          1
# thal        1
# num         1
# dtype: int64

# %%
df_copy = df_copy.dropna()

# %%
cols = ['age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal','num']
df_copy[cols] = df_copy[cols].apply(pd.to_numeric, errors='coerce').fillna(0).astype(int)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 292 entries, 0 to 291
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       292 non-null    int32
#  1   sex       292 non-null    int32
#  2   cp        292 non-null    int32
#  3   trestbps  292 non-null    int32
#  4   chol      292 non-null    int32
#  5   fbs       292 non-null    int32
#  6   restecg   292 non-null    int32
#  7   thalach   292 non-null    int32
#  8   exang     292 non-null    int32
#  9   oldpeak   292 non-null    int32
#  10  slope     292 non-null    int32
#  11  ca        292 non-null    int32
#  12  thal      292 non-null    int32
#  13  num       292 non-null    int32
# dtypes: int32(14)
# memory usage: 18.2 KB

# %%
df_copy
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     37    1   2       130   283    0        1       98      0        0
# 1     48    0   4       138   214    0        0      108      1        1
# 2     54    1   3       150    -9    0        0      122      0        0
# 3     39    1   3       120   339    0        0      170      0        0
# 4     45    0   2       130   237    0        0      170      0        0
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 287   48    0   2        -9   308    0        1       -9     -9        2
# 288   36    1   2       120   166    0        0      180      0        0
# 289   48    1   3       110   211    0        0      138      0        0
# 290   47    0   2       140   257    0        0      135      0        1
# 291   53    1   4       130   182    0        0      148      0        0
#
#      slope  ca  thal  num
# 0       -9  -9    -9    0
# 1        2  -9    -9    1
# ...

# %%
df_copy.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# num         0
# dtype: int64

# %% [markdown]
# There is no missing values in our dataset

# %% [markdown]
# #

# %% [markdown]
# ## Percentage of people having Heart Disease

# %%
num = df_copy.groupby('num').size()
num
# Out:
# num
# 0    187
# 1    105
# dtype: int64

# %%
# Converting Numerical Data into Categorical data

def heart_disease(row):
    if row == 0:
        return 'Negative'
    elif row == 1:
        return 'Positive'

# %%
# Applying Converted Data into our Dataset with New Column -Heart_Disease

df_copy['Heart_disease'] = df_copy['num'].apply(heart_disease)

# %%
df_copy.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   37    1   2       130   283    0        1       98      0        0     -9
# 1   48    0   4       138   214    0        0      108      1        1      2
# 2   54    1   3       150    -9    0        0      122      0        0     -9
# 3   39    1   3       120   339    0        0      170      0        0     -9
# 4   45    0   2       130   237    0        0      170      0        0     -9
#
#    ca  thal  num Heart_disease
# 0  -9    -9    0      Negative
# 1  -9    -9    1      Positive
# 2  -9    -9    0      Negative
# 3  -9    -9    0      Negative
# 4  -9    -9    0      Negative

# %%
hd = df_copy.groupby('Heart_disease')['num'].count()
hd
# Out:
# Heart_disease
# Negative    187
# Positive    105
# Name: num, dtype: int64

# %%
# Heart Disease Population % using Pie chart

plt.figure(figsize=(5,5))
plt.pie(hd, labels=['Negative','Positive'], autopct='%0.0f%%')
plt.title('Heart Disease Population %')
plt.show()

# %% [markdown]
#  - From the overall population, people having heart disease (36%) are lesser than those who have heart disease(64%)

# %% [markdown]
# #

# %%
#Countplot Creation of Population Age using MatplotLib and Seaborn

plt.figure(figsize=(15,7))
sns.countplot(x='age', data=df_copy)
plt.title('Population Age', fontsize=15)
plt.xlabel('Age',fontsize=12)
plt.ylabel('count', fontsize=12)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
#  - From this section, for best analysis is done by creating age groups
#          -Elderly_Ages
#          -Middle_Ages
#          -Young_Ages

# %% [markdown]
# #

# %% [markdown]
# Statistical Analysis

# %%
df_copy.describe().T
# Out:
#           count        mean        std   min    25%    50%    75%    max
# age       292.0   47.849315   7.824837  28.0   42.0   49.0   54.0   66.0
# sex       292.0    0.726027   0.446761   0.0    0.0    1.0    1.0    1.0
# cp        292.0    2.986301   0.966706   1.0    2.0    3.0    4.0    4.0
# trestbps  292.0  131.979452  19.429658  -9.0  120.0  130.0  140.0  200.0
# chol      292.0  230.493151  95.634416  -9.0  198.0  237.0  277.0  603.0
# fbs       292.0   -0.178082   1.504563  -9.0    0.0    0.0    0.0    1.0
# restecg   292.0    0.188356   0.709872  -9.0    0.0    0.0    0.0    2.0
# thalach   292.0  138.452055  25.072700  -9.0  122.0  140.0  155.0  190.0
# exang     292.0    0.273973   0.713354  -9.0    0.0    0.0    1.0    1.0
# oldpeak   292.0    0.547945   0.881908   0.0    0.0    0.0    1.0    5.0
# slope     292.0   -5.157534   5.217850  -9.0   -9.0   -9.0    2.0    3.0
# ca        292.0   -8.845890   1.387308  -9.0   -9.0   -9.0   -9.0    9.0
# ...

# %%
min_age = df_copy['age'].min()
mean_age = df_copy['age'].mean()
max_age = df_copy['age'].max()

print(f'Minimum Age : {min_age}')
print(f'Mean Age : {int(mean_age)}')
print(f'Maximum Age : {max_age}')
# Out:
# Minimum Age : 28
# Mean Age : 47
# Maximum Age : 66

# %% [markdown]
# #

# %% [markdown]
# Categorical Analysis

# %%
Young_Ages = df_copy[(df_copy['age']>=28) & (df_copy['age']<37)]
Middle_Ages = df_copy[(df_copy['age']>=37) & (df_copy['age']<47)]
Elderly_Ages = df_copy[(df_copy['age']>=47)]

print('Young Ages : ',len(Young_Ages))
print('Middle Ages : ',len(Middle_Ages))
print('Elderly Ages : ',len(Elderly_Ages))
# Out:
# Young Ages :  26
# Middle Ages :  90
# Elderly Ages :  176

# %%
# Age Category using Bar Plot

x_axis = ['Young_Ages', 'Middle_Ages', 'Elderly_Ages']
y_axis = [len(Young_Ages), len(Middle_Ages), len(Elderly_Ages)]

sns.barplot(x = x_axis, y = y_axis, palette = 'pastel')
plt.title('Age Category', fontsize=15)
plt.xlabel('Age Range', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #

# %%
#Converting Numerical Data into Categorical Data

def gender(row):
    if row==1:
        return 'Male'
    elif row==0:
        return 'Female'

# %%
#Applying converted data into our dataset with new column - Gender

df_copy['Gender'] = df_copy['sex'].apply(gender)
df_copy.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   37    1   2       130   283    0        1       98      0        0     -9
# 1   48    0   4       138   214    0        0      108      1        1      2
# 2   54    1   3       150    -9    0        0      122      0        0     -9
# 3   39    1   3       120   339    0        0      170      0        0     -9
# 4   45    0   2       130   237    0        0      170      0        0     -9
#
#    ca  thal  num Heart_disease  Gender
# 0  -9    -9    0      Negative    Male
# 1  -9    -9    1      Positive  Female
# 2  -9    -9    0      Negative    Male
# 3  -9    -9    0      Negative    Male
# 4  -9    -9    0      Negative  Female

# %%
#Converting Numerical Data into Categorical Data

def age_range(row):
    if row>=28 and row<37:
        return 'Young Age'
    elif row>=37 and row<47:
        return 'Middle Age'
    elif row>=47:
        return 'Elder Age'

# %%
df_copy['Age_Range']=df_copy['age'].apply(age_range)
df_copy.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   37    1   2       130   283    0        1       98      0        0     -9
# 1   48    0   4       138   214    0        0      108      1        1      2
# 2   54    1   3       150    -9    0        0      122      0        0     -9
# 3   39    1   3       120   339    0        0      170      0        0     -9
# 4   45    0   2       130   237    0        0      170      0        0     -9
#
#    ca  thal  num Heart_disease  Gender   Age_Range
# 0  -9    -9    0      Negative    Male  Middle Age
# 1  -9    -9    1      Positive  Female   Elder Age
# 2  -9    -9    0      Negative    Male   Elder Age
# 3  -9    -9    0      Negative    Male  Middle Age
# 4  -9    -9    0      Negative  Female  Middle Age

# %% [markdown]
# #

# %%
# Creation of Gender Based Age Category using Swarm plot

plt.figure(figsize=(10,7))
sns.swarmplot(x='Age_Range', y='age', hue='Gender', data=df_copy,
              order=['Young Age','Middle Age','Elder Age'],palette='Oranges_r')
plt.title('Gender Based Age Category',fontsize=15)
plt.xlabel('Age Category', fontsize=12)
plt.ylabel('Age', fontsize=12)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(10,7))
sns.swarmplot(x='Age_Range', y='age', hue='Gender', data=df_copy, order=['Young Age','Middle Age','Elder Age'], palette='Oranges_r')
plt.title('Gender Based Age Category', fontsize=17)
plt.xlabel('Age Category', fontsize=15)
plt.ylabel('Age', fontsize=15)
plt.show()

# %%
sns.catplot(
    data=df_copy, kind="swarm",
    x="Age_Range", y="age", hue="Gender",
    aspect=1.0
)

# %% [markdown]
# #

# %%
# Heart Disease Based On Age Category using Count Plot

plt.figure(figsize=(7,5))
hue_order = ['Young Age', 'Middle Age', 'Elder Age']
sns.countplot(x='Heart_disease', hue='Age_Range', data=df_copy,
              order=['Positive','Negative'], hue_order=hue_order, palette='Pastel1')
plt.title('Heart Disease Based On Age Category', fontsize=17)
plt.xlabel('Heart Disease', fontsize=15)
plt.ylabel('Counts', fontsize=15)
plt.show()

# %% [markdown]
#  - From the above, Ratio of Negative is greater then Positive

# %% [markdown]
# #

# %%
# Heart Disease Based on Gender using Count Plot

plt.figure(figsize=(7,5))
sns.countplot(x=df_copy['Heart_disease'], hue='Gender',data=df_copy, palette='BuGn_r')
plt.title('Heart Disease Based on Gender',fontsize=17)
plt.xlabel('Heart Disease',fontsize=12)
plt.ylabel('Count',fontsize=12)
plt.show()

# %% [markdown]
#  - We can see the Males are more pron to Heart Disease.

# %% [markdown]
# #

# %%
# Chest Pain Experience Using Count Plot

plt.figure(figsize=(9,5))
sns.countplot(x='Heart_disease', hue='cp',data=df_copy,order=['Positive','Negative'])
plt.title('Chest Pain Experience',fontsize=17)
plt.xlabel('Heart Disease',fontsize=12)
plt.ylabel('Count',fontsize=12)
plt.legend(labels=['Typical Angina','Atypical Angina','Non-Anginal pain','Asymptomatic'],)
plt.show()

# %% [markdown]
# -> From above:
#
#      - People having asympttomatic chest pain have a higher chance of heart disease.
#      - Asymptomatic Chest pain means neither causing nor exhibiting symptoms of Heart disease.

# %% [markdown]
# #

# %%
# Chest Pain Based on Gender using Count Plot

sns.countplot(x='Gender', hue='cp', data=df_copy)
plt.title('Chest Pain Based on Gender',fontsize=17)
plt.xlabel('Gender', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.legend(labels=['Typical Angina','Atypical Angina','Non-Anginal pain','Asymptomatic'])
plt.show()

# %% [markdown]
#  - From above, it seems that higher number of Male suffering from Asymptomatic Chest pain and Atypical Angina Chest pain

# %% [markdown]
# #

# %%
# Chest Pain Based on Age Range Category using Count Plot

sns.countplot(x='Age_Range',hue='cp',data=df_copy,
              order = ['Young Age', 'Middle Age', 'Elder Age'],palette='BrBG')
plt.title('Chest Pain Based on Age Range Category',fontsize=17)
plt.xlabel('Age Range Category',fontsize=12)
plt.ylabel('count',fontsize=12)
plt.legend(labels=['Typical Angina','Atypical Angina','Non-Anginal pain','Asymptomatic'])
plt.show()

# %% [markdown]
#  - From above, there is very high number of Asymptomatic Pain in Elderly age Category

# %% [markdown]
# #

# %%
# Person's Resting Blood Pressure (mm Hg) using Bar Plot

sns.barplot(x='Gender',y='trestbps',data=df_copy,palette='plasma')
plt.title('Blood Pressure', fontsize=17)
plt.xlabel('Gender',fontsize=12)
plt.ylabel("Person's Resting Blood Pressure (mm Hg)",fontsize=12)
plt.show()

# %% [markdown]
#  - Blood Pressure Rate is almost equal in Males and Females

# %% [markdown]
# #

# %%
# Chloestrol Level based on Gender using Bar Plot

sns.barplot(x='Gender',y='chol',data=df_copy,palette='turbo')
plt.title('Chloestrol Level Based On Gender', fontsize=17)
plt.xlabel('Gender',fontsize=12)
plt.ylabel('Cholestrol',fontsize=12)
plt.show()

# %% [markdown]
#  - Male has little bit higher cholestrol then female

# %% [markdown]
# #

# %%
# Cholestrol vs Heart Disease using Bar Plot

sns.barplot(x='Heart_disease',y='chol',data=df_copy,palette='ocean_r')
plt.title('Cholestrol vs Heart Disease',fontsize=17)
plt.xlabel('Heart Disease',fontsize=12)
plt.ylabel('Cholestrol',fontsize=12)
plt.show()

# %% [markdown]
#  - Higher Cholestrol Level results Chances Of Heart Disease

# %% [markdown]
# #

# %%
# Blood Pressure vs Heart Disease using Bar Plot

sns.barplot(x='Heart_disease', y='trestbps',data=df_copy,palette='tab20b_r')
plt.title('Blood Pressure vs Heart Disease',fontsize=17)
plt.xlabel('Heart Disease',fontsize=12)
plt.ylabel('Blood Pressure',fontsize=12)
plt.show()

# %% [markdown]
#  - Higher Blood Pressure Level results Chances Of Heart Disease

# %% [markdown]
# #

# %%
# Blood Pressure vs Age using Line Plot

sns.lineplot(x='age', y='trestbps',data=df_copy,color='r')
plt.title('Blood Pressure vs Age',fontsize=17)
plt.xlabel('Age',fontsize=12)
plt.ylabel('Blood Pressure',fontsize=12)
plt.show()

# %% [markdown]
#  - Hear we can observe that as the Age is increases the problem of Blood Pressure is also increases.

# %% [markdown]
# #

# %%
# Cholestrol vs Age using Line Plot

sns.lineplot(x='age',y='chol',data=df_copy,color='g')
plt.title('Cholestrol vs Age',fontsize=17)
plt.xlabel('Age',fontsize=12)
plt.ylabel('Cholestrol',fontsize=12)
plt.show()

# %% [markdown]
#  - Cholestrol slightly increase in the aage group between 50-60

# %% [markdown]
# #

# %%
# ST Depression vs Age using Line Plot

sns.lineplot(x='age',y='oldpeak',data=df_copy,color='b')
plt.title('ST Depression vs Age',fontsize=17)
plt.xlabel('Age',fontsize=12)
plt.ylabel('ST Depression',fontsize=12)
plt.show()

# %% [markdown]
#  - From above we can observe that the Depression level is increase as an Age is increases

# %% [markdown]
# #

# %%
# ST Depression vs Heart Disease using Bar Plot

sns.barplot(x='Gender',y='oldpeak',data=df_copy,palette='twilight_r')
plt.title('ST Depression vs Heart Disease',fontsize=17)
plt.xlabel('Gender',fontsize=12)
plt.ylabel('ST Depression',fontsize=12)
plt.show()

# %% [markdown]
#  - Depression level is increases in Male as compair to Female

# %% [markdown]
# #

# %%
# Exercise With Angina VS Heart Disease using Bar Plot

sns.barplot(x='Heart_disease',y='exang',data=df_copy,palette='viridis')
plt.title('Exercise With Angina VS Heart Disease',fontsize=17)
plt.xlabel('Heart Disease',fontsize=12)
plt.ylabel('Exercise With Angina',fontsize=12)
plt.show()

# %% [markdown]
#  - If you suffer from Angina, you may be concerned that exercise will make your symptoms worse

# %% [markdown]
# #

# %%
#  Exercise With Angina VS Gender using Bar Plot

sns.barplot(y='exang',x='Gender',data=df_copy,palette='binary_r')
plt.title('Exercise With Angina VS Gender',fontsize=17)
plt.xlabel('Gender',fontsize=12)
plt.ylabel('Exercise With Angina',fontsize=12)
plt.show()

# %% [markdown]
#  - Male have high Exercise Agnia
#  - A type of chest pain caused by reduced blood flow to the heart

# %% [markdown]
# #

# %%
# Fasting Blood Sugar VS Gender using Bar Plot

sns.barplot(x='Gender',y='fbs',data=df_copy,palette='hsv')
plt.title('Fasting Blood Sugar VS Gender',fontsize=17)
plt.xlabel('Gender',fontsize=12)
plt.ylabel('Fasting Blood Sugar',fontsize=12)
plt.show()

# %%
df_copy.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000  0.016657  0.142829  0.223343  0.046324  0.045583
# sex       0.016657  1.000000  0.253854  0.128803  0.028509  0.090762
# cp        0.142829  0.253854  1.000000  0.104636  0.119168  0.003042
# trestbps  0.223343  0.128803  0.104636  1.000000  0.019023  0.061589
# chol      0.046324  0.028509  0.119168  0.019023  1.000000 -0.110967
# fbs       0.045583  0.090762  0.003042  0.061589 -0.110967  1.000000
# restecg  -0.007865 -0.096778  0.078887 -0.035845  0.031580 -0.007096
# thalach  -0.429963 -0.071430 -0.323850 -0.016297 -0.093646 -0.002049
# exang     0.152712  0.171637  0.364251  0.453632  0.074779  0.020000
# oldpeak   0.165881  0.129394  0.327266  0.128408  0.133361  0.042715
# slope     0.230117  0.056603  0.374952  0.127350  0.170130  0.001229
# ca        0.036335 -0.031444  0.070763  0.057487 -0.073072  0.013193
# thal      0.006646  0.012969  0.074923 -0.026430  0.067230 -0.091946
# ...

# %%
# Heatmap 

plt.figure(figsize=(16,9))
sns.heatmap(df_copy.corr(),annot=True,linewidths=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
df_copy.to_csv('cleaned.hungarian.csv', index=False)

# %%
pwd
# Out:
# 'C:\\Users\\swapn'
